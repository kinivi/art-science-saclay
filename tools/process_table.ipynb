# %%
import pandas as pd

# %%
df=pd.read_csv("apple.csv")

# %%
# iterate over rows and print the values
for index, row in df.iterrows():
    print("Q:"+row.Question)
    print("A:"+row.Reaction)
    print("\n")
# Out:
# Q:Who are you?
# A:I’m A-P-P-L-E
# I’m round, green, and tasty!
#
#
# Q:What’s your story?
# A:I’m that apple of the snow white.
#
#
# Q:How do you see yourself?
# A:Who’s the most beautiful goddess?
#
#
# Q:Can I have you for 5 euros?
# A:Am I only 5 euros per kilo?
#
#
# Q:What are you doing tomorrow?
# A:I want to see the world, take me to your next trip.
#
#
# Q:Hello, How are you?
# A:Hello, Sweetie
#
#
# Q:Is everything good?
# A:I’m tired…I need more sunlight.
#
#
# Q:How are you doing?
# A:If you were in my shoes, what would you think?
#
#
# Q:Hey apple?
# A:Pen-pineapple-apple-pen
#
#
# Q:Why are you so ugly?
# A:I had a teenager-mom, that’s why I’m so thin.
#
#
# Q:What was your childhood like?
# A:Apple Kindergarten was a nightmare, we had to scream to talk to the others from the tree.
#
#
# Q:How old are you?
# A:A lady never reveals her age.
#
#
# Q:Can you speak?
# A:Waah Waaaaah
#
#
# Q:Are you meeting someone?
# ...
